# %%
import pandas as pd

# %% [markdown]
# # Zuerst anschauen mit Geburten pro 1000:

# %%
df = pd.read_excel("gpzuerich.xlsx")

# %%
df["Diff19"] = ((100/df[2018]*df[2019])-100).round(1)

# %%
df2 = df
df2
# Out:
#      BFS_NR     GEBIET_NAME  2019  2018  2017  2016  2015  2014  2013  2012  \
# 0        21         Adlikon   9.9  16.8  22.7  13.6  19.7   3.5   7.1   6.9
# 1       131        Adliswil  12.5  12.3  12.2  10.8  12.1  15.0  11.7  12.2
# 2       241        Aesch ZH  10.3  20.1  14.2  10.9  13.5   7.6  11.2  12.9
# 3         1     Aeugst a.A.   9.1   8.8   5.1   7.0   9.7   9.6   9.7  10.5
# 4         2  Affoltern a.A.  12.9  12.9  10.8  12.0  10.0  10.9   9.5   9.9
# ..      ...             ...   ...   ...   ...   ...   ...   ...   ...   ...
# 171     230      Winterthur  11.7  11.7  12.7  11.7  12.6  12.2  12.1  11.9
# 172     231            Zell  10.0  11.0  11.3  11.8  13.5  10.5  10.9  11.1
# 173     161        Zollikon  10.1  11.0  10.7  11.2  12.3  11.4  10.9   9.3
# 174     160         Zumikon   6.3   6.8   6.2   5.6   7.4   5.8   6.4   8.5
# 175     261          Zürich  12.4  12.9  13.2  13.2  13.3  13.4  12.8  12.5
#
# ...

# %%
for x in range (1991, 2020):
    df2["Diff"+str(x)] = ((100/df2[(x-1)]*df2[x])-100).round(1)
df2
# Out:
#      BFS_NR     GEBIET_NAME  2019  2018  2017  2016  2015  2014  2013  2012  \
# 0        21         Adlikon   9.9  16.8  22.7  13.6  19.7   3.5   7.1   6.9
# 1       131        Adliswil  12.5  12.3  12.2  10.8  12.1  15.0  11.7  12.2
# 2       241        Aesch ZH  10.3  20.1  14.2  10.9  13.5   7.6  11.2  12.9
# 3         1     Aeugst a.A.   9.1   8.8   5.1   7.0   9.7   9.6   9.7  10.5
# 4         2  Affoltern a.A.  12.9  12.9  10.8  12.0  10.0  10.9   9.5   9.9
# ..      ...             ...   ...   ...   ...   ...   ...   ...   ...   ...
# 171     230      Winterthur  11.7  11.7  12.7  11.7  12.6  12.2  12.1  11.9
# 172     231            Zell  10.0  11.0  11.3  11.8  13.5  10.5  10.9  11.1
# 173     161        Zollikon  10.1  11.0  10.7  11.2  12.3  11.4  10.9   9.3
# 174     160         Zumikon   6.3   6.8   6.2   5.6   7.4   5.8   6.4   8.5
# 175     261          Zürich  12.4  12.9  13.2  13.2  13.3  13.4  12.8  12.5
#
# ...

# %%
df3 = df2.drop(columns=["BFS_NR", 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
df3
# Out:
#         GEBIET_NAME  Diff19  Diff1991  Diff1992  Diff1993  Diff1994  Diff1995  \
# 0           Adlikon   -41.1       2.1      -1.0      -6.8     -20.1      22.4
# 1          Adliswil     1.6       7.8      -9.0       5.9      -9.3       8.2
# 2          Aesch ZH   -48.8      22.6     -69.7      68.9     -60.2     102.4
# 3       Aeugst a.A.     3.4     -14.2      -9.0     -12.4       0.0       4.7
# 4    Affoltern a.A.     0.0      -7.5      12.8     -17.4       8.0     -10.1
# ..              ...     ...       ...       ...       ...       ...       ...
# 171      Winterthur    -0.0      -5.8       1.8       1.7       0.8      -1.7
# 172            Zell    -9.1     -22.2       2.7      -7.8      30.2     -31.2
# 173        Zollikon    -8.2       7.7      -7.1      -7.7      -7.1      11.5
# 174         Zumikon    -7.4     -22.4      39.4     -18.5      17.3     -14.8
# 175          Zürich    -3.9      10.1       0.0       2.0       2.0      -2.0
#
# ...

# %%
df3.to_excel("change.xlsx")

# %% [markdown]
# # Jetzt mit absoluten Zahlen:

# %%
df4 = pd.read_excel("geb_absolut.xlsx")
for x in range (1991, 2020):
    df4["Diff"+str(x)] = (df4[x]-df4[(x-1)]).round(1)

# %%
df5 = df4.drop(columns=["BFS_NR", 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019])

# %%
df5.to_excel("change_absolut.xlsx")
