# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("https://www.kantonsrat.zh.ch/mitglieder/")
soup = BeautifulSoup(r.text, "html.parser")

# %%
a_list = soup.find_all("body")

# %%
a_list[0:]
# Out:
# [<body>
#  <div data-server-rendered="true" id="__nuxt"><!-- --><div id="__layout"><div class="Layout"><div class="Browserupgrade"><div class="Browserupgrade__text"><h3>Sie verwenden einen <strong>veralteten</strong> Browser.</h3> <p>
#          Seit dem 12. Januar 2016<a href="#outdatedRef01"><sup>[1]</sup></a>, werden der Internet Explorer 11 und Ã¤ltere Versionen davon nicht
#          mehr lÃ¤nger von Microsoft unterstÃ¼tzt und werden als
#          <strong>unsicher</strong> betrachtet.
#          <br/> <br/>Bitte aktualisieren Sie ihren Browser fÃ¼r eine optimale Nutzung
#          dieser Seite. <br/>Alternativ verwenden Sie einen neuen Browser:
#        </p> <ul><li><a href="https://www.firefox.com/">Mozilla Firefox</a></li> <li><a href="https://www.google.com/chrome">Google Chrome</a></li></ul> <br/>Ref <a name="outdatedRef01">[1]</a>:
#        <a href="https://www.microsoft.com/en-us/WindowsForBusiness/End-of-IE-support">Microsoft:
# ...
